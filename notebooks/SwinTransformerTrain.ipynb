# %%
# !python -m pip install --upgrade pip
# !python -m pip install PyYAML --upgrade PyYAML

# %%
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# %%
# !git clone https://github.com/SoulOfWindTGN/Swin-Transformer.git
# %cd Swin-Transformer

# %%
# !pip install timm

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd apex

# %%
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./

# %%
# !pip install opencv-python==4.4.0.46 termcolor==1.1.0 yacs==0.1.8

# %%
# !nvidia-smi

# %%
# %cd /kaggle/working/Swin-Transformer

# %%
# !python -m torch.distributed.launch --nproc_per_node 1 --master_port 12345  main.py \
--cfg configs/swin_tiny_patch4_window7_224.yaml --data-path /kaggle/input/bali26/Bali --batch-size 128 --output /kaggle/working

# %%
import shutil
shutil.make_archive("/kaggle/working/swin_tiny_patch4_window7_224", 'zip', "/kaggle/working/swin_tiny_patch4_window7_224")
